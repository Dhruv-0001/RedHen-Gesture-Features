# %%
! pip install requests ffmpeg-python
! pip install deepgram-sdk --upgrade

# %%
from deepgram import Deepgram
import asyncio, json, os

dg_key = '' # get it by signup on the platform.
dg = Deepgram(dg_key)

'''
The most common audio formats and encodings we support
include mp3, mp4, mp2, aac, wav, flac, pcm, m4a, ogg, opus, and webm,
So feel free to adjust the `MIMETYPE` variable as needed
'''
MIMETYPE = 'mp4'

#Note: You can use '.' if your audio is in the root
DIRECTORY = '/content/'


# Feel free to modify your model's parameters as you wish!
options = {
    "punctuate": True,
    "diarize": True,
    "model": 'general',
    "tier": 'nova'
}

#This function is what calls on the model to transcribe
def main():
    audio_folder = os.listdir(DIRECTORY)
    for audio_file in audio_folder:
        if audio_file.endswith(MIMETYPE):
          with open(f"{DIRECTORY}/{audio_file}", "rb") as f:
              source = {"buffer": f, "mimetype":'audio/'+MIMETYPE}
              res = dg.transcription.sync_prerecorded(source, options)
              with open(f"./{audio_file[:-4]}.json", "w") as transcript:
                  json.dump(res, transcript, indent=4)
    return

main()

# %%
'''
The JSON is loaded with information, but if you just want to read the
transcript, run the code below!

One .txt file will be generated per JSON; this .txt file will contain
the diarized, human-readable transcript.
'''

TAG = 'SPEAKER '

def create_transcript(output_json, output_transcript):
  lines = []
  with open(output_json, "r") as file:
    words = json.load(file)["results"]["channels"][0]["alternatives"][0]["words"]
    curr_speaker = 0
    curr_line = ''
    for word_struct in words:
      word_speaker = word_struct["speaker"]
      word = word_struct["punctuated_word"]
      if word_speaker == curr_speaker:
        curr_line += ' ' + word
      else:
        tag = TAG + str(curr_speaker) + ':'
        full_line = tag + curr_line + '\n'
        curr_speaker = word_speaker
        lines.append(full_line)
        curr_line = ' ' + word
    lines.append(TAG + str(curr_speaker) + ':' + curr_line)
    with open(output_transcript, 'w') as f:
      for line in lines:
        f.write(line)
        f.write('\n')
  return

def print_transcript():
  for filename in os.listdir(DIRECTORY):
    if filename.endswith('.json'):
      output_transcript = os.path.splitext(filename)[0] + '.txt'
      create_transcript(filename, output_transcript)

print_transcript()

# %%
SEPARATOR = '--------------------------'

def print_lines(filename):
  with open(filename, 'r') as f:
    for line in f:
      print(line)

def print_transcript():
  for filename in os.listdir(DIRECTORY):
    if filename.endswith('.txt'):
      print_lines(filename)
      print(SEPARATOR)

print_transcript()
# Out:
# SPEAKER 0: Series called Sonic Highway features. My hometown in New Orleans is so, so good. Please welcome eleven time Grammy award winner. Dave Groll series called Sonic Highway features. My hometown in New Orleans is so, so good. Please welcome eleven time Grammy award winner Dave Groll Hey, Dave.
#
#
#
# SPEAKER 1: Hi, Alan.
#
#
#
# SPEAKER 0: How are you?
#
#
#
# SPEAKER 1: I'm alright. How are you?
#
#
#
# SPEAKER 0: I I'm good. How old is it? You have a brand new child. Hey, Dave.
#
#
#
# SPEAKER 1: Hi, Alan.
#
#
#
# SPEAKER 0: How are you? I'm alright.
#
#
#
# SPEAKER 1: How are you?
#
#
#
# SPEAKER 0: I I'm good. How old is you have a brand new child?
#
#
#
# SPEAKER 1: I have a brand new child.
#
#
#
# SPEAKER 0: How old is the child?
#
#
#
# SPEAKER 1: I have a brand new show. How
#
#
#
# SPEAKER 0: old is the child?
#
#
#
# SPEAKER 1: She's three months old.
#
#
#
# SPEAKER 0: That's pretty new.
#
#
#
# SPEAKER 1: She's a brand new baby. Wow. She's my third. She's three months old.
#
#
#
# SPEAKER 0: That's pretty new.
#
#
#
# SPEAKER 1: She's a brand new baby. Wow. She's my third. So
#
#
#
# SPEAKER 0: Yeah. You have three. You have how old are the other two?
#
#
#
# SPEAKER 1: So
#
#
#
# SPEAKER 0: Yeah. You have three. You have how old are the other two?
#
#
#
# SPEAKER 1: Violet is eight years old. Mhmm. Harper is five years old. Mhmm. Ophelia is three months old.
#
#
#
# SPEAKER 0: Ophelia St. Right?
#
#
#
# SPEAKER 1: Ophelia St. Violett is eight years old. Mhmm. Harper is five years old. Mhmm. Ophelia's three months old.
#
#
#
# SPEAKER 0: Ophelia's saint. Right?
#
#
#
# SPEAKER 1: Ophelia's saint.
#
#
#
# SPEAKER 0: I like it.
#
#
#
# SPEAKER 1: Groll.
#
#
#
# SPEAKER 0: I like it.
#
#
#
# SPEAKER 1: That's good.
#
#
#
# SPEAKER 0: That's a good name. Thanks. What does she look like? We don't have a picture of her. So
#
#
#
# SPEAKER 1: She looks like oh, here we go. That's good.
#
#
#
# SPEAKER 0: That's a good name. Thanks. What does she look like? We don't have a picture of her. So
#
#
#
# SPEAKER 1: She looks like oh, here we go. She kind of
#
#
#
# SPEAKER 0: People like to see pictures of babies and we don't have one. So Okay.
#
#
#
# SPEAKER 1: I'll show you what she sort of looks like. She kinda looks like this right now.
#
#
#
# SPEAKER 0: She's adorable.
#
#
#
# SPEAKER 1: She kind of
#
#
#
# SPEAKER 0: People like to see pictures of babies and we don't have one. So Okay.
#
#
#
# SPEAKER 1: I'll show you what she sort of looks like. She kinda looks like this right now.
#
#
#
# SPEAKER 0: She's adorable.
#
#
#
# SPEAKER 1: She has huge, blue eyes. She smiles a lot. She has huge, blue eyes. She smiles a lot. And she weighs about thirty six pounds. Oh, it's horrible. So That's good. And she weighs about thirty six pounds. Oh, it's horrible. So That's cute.
#
#
#
# SPEAKER 0: This is the door. Thank you. Yeah. Yeah. Thank you so much. You can
#
#
#
# SPEAKER 1: see the resemblance.
#
#
#
# SPEAKER 0: Yeah. Yeah. Cute. This is
#
#
#
# SPEAKER 1: the door.
#
#
#
# SPEAKER 0: Thank you.
#
#
#
# SPEAKER 1: Yeah. Yeah.
#
#
#
# SPEAKER 0: Thank you so much. You see the resemblance. Yeah. Yeah. Cute. And you have so you have the the other two now a brand new one you have so you have the the other two now a brand new one. And this is true because I saw in the documentary, I saw you interviewed on sixty minutes. And this is true because I saw in the documentary, I saw you interviewed on sixty minutes. You you drive your kids to school every single morning. Yeah. You you drive your kids to school every single morning. Yeah. And then you play music.
#
#
#
# SPEAKER 1: Well, my day starts at like about five
#
#
#
# SPEAKER 0: And then you play music.
#
#
#
# SPEAKER 1: Well, my day starts at, like, about five forty five. Mhmm. So I get up and I get in the shower and I get my forty five. Mhmm. So I get up and I get in the shower and I get my act together, and then I gotta get them up out of bed, but then I gotta get the snack pack together, and then I gotta get them up out of bed, but then I gotta get the snack packs going. And while I'm getting the snack packs going, they come into the kitchen, then I get the breakfast going. Going. And while I'm getting the snack packs going, they come into the kitchen, then I get the breakfast going. Once they've had breakfast, I get them dressed, and they get dressed, and I get the backpacks and the snack packs. Once they've had breakfast, I get them dressed, and they get dressed, and I get the backpacks and the snack packs into my minivan, and then I get them in the minivan. Into my minivan, and then I get them in the minivan, and then I sit in traffic for forty five minutes, and then I get them to school, and then I drive forty five minutes back to my house, and then I start my day. And I sit in traffic for forty five minutes, and then I get him to school, and I drive forty five minutes back to my house, and then I start my day. That sounds good. So
#
#
#
# SPEAKER 0: I love that so much. Yeah. I mean,
#
#
#
# SPEAKER 1: that sounds.
#
#
#
# SPEAKER 0: So I love that so
#
#
#
# SPEAKER 1: much. Yeah.
#
#
#
# SPEAKER 0: I mean, I think when people see you on tour, I think when people see you on tour and see you perform, they're not that's not the image they have in their head. Is you in a minivan?
#
#
#
# SPEAKER 1: Not with, like, the bottle of Jack Daniels.
#
#
#
# SPEAKER 0: So you perform? They're not that's not the image they have in their head. Is you in a minivan?
#
#
#
# SPEAKER 1: Not with, like, the bottle of Jack Daniels. Like driving a minivan in
#
#
#
# SPEAKER 0: the valley. Now, what kind of music when when they're, in the car,
#
#
#
# SPEAKER 1: driving a minivan in the back.
#
#
#
# SPEAKER 0: Now, what kind of music? When when they're, in the car, Do you get to play the music? Do you wanna hear
#
#
#
# SPEAKER 1: or do
#
#
#
# SPEAKER 0: they have control?
#
#
#
# SPEAKER 1: Never, ever.
#
#
#
# SPEAKER 0: And what do they listen to?
#
#
#
# SPEAKER 1: Well, you know, I try to brainwash
#
#
#
# SPEAKER 0: Do you get to play the music? Do you wanna hear
#
#
#
# SPEAKER 1: or do
#
#
#
# SPEAKER 0: they have control?
#
#
#
# SPEAKER 1: Never, ever. And
#
#
#
# SPEAKER 0: what do they listen to?
#
#
#
# SPEAKER 1: Well, you know, I try to brainwash them with like beetles and rolling stones and stuff like that. Them with, like, Beatles and Rolling Stones and stuff like that. But at the end of the day, it's, like, the it's all about that base. Whatever. They'll hear, like, the end of the day, it's like the it's all about that base. Whatever. They'll hear. Like, there there's that. And Katie Perry is huge. My daughter Harper, who Yeah. There's that. And Katie Perry is huge. My daughter Harper, who's five, will sing a Katy Perry. I don't even know if she knows the words, they're probably not even words. Five will sing a Katy Perry. I don't even know if she knows the words, they're probably not even words, but she'll sing these Katy Perry songs like they're her own songs. But she'll sing these Katy Perry songs like they're her own songs. It's it's it's good. I went to she played in here in Los Angeles, and I took It's just it's great. I went to she played it here in Los Angeles, and I took four moms and, like, eight kids to go see Katie Perry. Four moms and, like, eight kids to go see Katie Perry. Uh-huh. Backstage, they had this candy bar, you know, about this. They they backstage, they had this candy bar, you know, about this? There's, like, this massive bar with, like, pixie sticks and twizzlers and skittles and, like, this massive, this massive bar with, like, pixie sticks and twizzlers and skittles and, like, this massive, huge table of it, huge table of it, and the kids are just like, so that when she goes on stage, you're like Yeah. Yeah. And what And the kids are just like, so that when she goes on stage, you're like, yeah.
#
#
#
# SPEAKER 0: Yeah. It works. It, like, totally works.
#
#
#
# SPEAKER 1: To, like, totally work.
#
#
#
# SPEAKER 0: It totally works.
#
#
#
# SPEAKER 1: That's amazing.
#
#
#
# SPEAKER 0: That's the way to manipulate your audience.
#
#
#
# SPEAKER 1: I know. We do that, but with other things.
#
#
#
# SPEAKER 0: With other things. Yeah. Amazing. That's the way to manipulate your audience.
#
#
#
# SPEAKER 1: I know. We do that. Those kind of things.
#
#
#
# SPEAKER 0: With other things. Yeah. So this, this Docu series is an eight part. And if you haven't watched it, it is it's so good So this, this Docu series is an eight part. And if you haven't watched it, it is it's so good. I'll let you explain it and and how you came up with the idea. I'll let you explain it and and how you came up with the idea.
#
#
#
# SPEAKER 1: Well, the last two fighters record that we made we made in my garage. Well, the last two fighters record that we made we made in my garage, because I wanted to take the band out of our comfort zone, like, which is our own studio, because I wanted to take the band out of our comfort zone, like, which is our own studio, and see how the environment influences the and see how the environment influences the outcome of the music. Then I made the Sound City documentary, which is a documentary about a studio in Los Angeles, and I'd never done that before. Come of the music. Then I made the Sound City documentary, which is a documentary about a studio in Los Angeles, and I'd never done that before.
#
#
#
# SPEAKER 0: That was a great document.
#
#
#
# SPEAKER 1: It turned out alright. And but the response to it was really great. People would come up to me all the time. So, like, man, I was really inspired by that movie.
#
#
#
# SPEAKER 0: That was a great time.
#
#
#
# SPEAKER 1: It turned out alright. And but the response to it was really great. People would come up to me all the time and say, man, I was really inspired by that movie. I never considered I never considered the studio owners and the places where albums are recorded. And it gave everyone a new appreciation for how the studio owners and the places where albums are recorded. And it gave everyone a new appreciation for how music is made or for, given to people. Music is made or for, given to people. So I put those two ideas together where I thought I'm gonna challenge the band, not in one So I put those two ideas together where I thought I'm gonna challenge the band, not in one environment, but in eight different environments, eight cities all across America. Environment, but in eight different environments, eight cities all across America. And I'm not gonna make one documentary movie. I'm gonna do and I'm not gonna make one documentary movie. I'm gonna do eight, one hour episodes for a series. Eight, one hour episodes for a series. And the idea is that we go to a city for six days And the idea is that we go to a city for six days. We load into a weird little studio in town, and we start recording a song that we have no lyrics for. We load into a weird little studio in town, and we start recording a song that we have no lyrics for. And as we're recording, I go out at night, and I interview people from that city. Like in New Orleans, it's And as we're recording, I go out at night, and I interview people from that city. Like in New Orleans, it's, doc Doctor. John and Trombone Shordy, and, Cyril Neville and Alan Tussain. All the famous people from each city, I interview them about the city John and Trombone Shordy and, Cyril Neville and Allen to Saint. All the famous people from each city, I interview them about the city and how that environment influenced the music. And then at the end of the week, I write the song. And how that environment influenced the music. And then at the end of the week, I write the song. So the day before I have to sing and I sit down with all of the transcripts and the interviews, and I pick out words and phrases, and I So the day before I have to sing it, I sit down with all of the transcripts and the interviews, and I pick out words and phrases, and I I sort of shape it into a song, and then I sing it the last day. We're there. And so we did that all over the country for about six months.
#
#
#
# SPEAKER 0: It's it's so fantastic and so interesting.
#
#
#
